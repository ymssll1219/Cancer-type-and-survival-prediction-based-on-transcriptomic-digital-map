# %%
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index

# %%
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\BLCA1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\BLCA2.csv')

# %%
# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7','RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]

# %%
# 打印所有列名
print("df1 列名:", df1.columns)
print("df2 列名:", df2.columns)
# Out:
# df1 列名: Index(['event', 'SurvivalTime', 'CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7',
#        'RALA', 'MDH1', 'NFE2L2', 'ATP5MC1', 'PCMT1', 'ZFAND5'],
#       dtype='object')
# df2 列名: Index(['event', 'SurvivalTime', 'CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7',
#        'RALA', 'MDH1', 'NFE2L2', 'ATP5MC1', 'PCMT1', 'ZFAND5'],
#       dtype='object')

# %%
# 打印 'days_to_death' 列的前几个样本值
#print("df1 'SurvivalTime' 列样本值:", df1['SurvivalTime'].head())
print("df2 'event' 列样本值:", df2['event'].head())
# Out:
# df2 'event' 列样本值: 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: event, dtype: int64

# %%
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))

# %%
# 创建 Cox 模型
cph = CoxPHFitter()

# %%
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# Out:
# <lifelines.CoxPHFitter: fitted with 96 total observations, 5 right-censored observations>

# %%
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values


# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values

# %%
print("event_times shape:", df1['SurvivalTime'].shape)
print("predicted_scores shape:", predicted_survival_1.shape)

print("event_times shape:", df2['SurvivalTime'].shape)
print("predicted_scores shape:", predicted_survival_2.shape)
# Out:
# event_times shape: (95,)
# predicted_scores shape: (83, 95)
# event_times shape: (96,)
# predicted_scores shape: (83, 96)

# %%
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)

# %%
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# Out:
# <lifelines.CoxPHFitter: fitted with 191 total observations, 5 right-censored observations>

# %%
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)

# %%
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.6703144862654065

# %%
import matplotlib.pyplot as plt

# 对整个数据集进行生存曲线预测
predicted_survival = cph.predict_survival_function(df)

# %%
# 绘制 Cox 生存曲线图
plt.figure(figsize=(10, 6))

# 绘制前半组的生存曲线
for i in range(len(df1)):
    plt.step(predicted_survival.index, predicted_survival.iloc[:, i], where="post", label=f"Individual {i + 1} (First Half)")

# 绘制后半组的生存曲线
for i in range(len(df2)):
    plt.step(predicted_survival.index, predicted_survival.iloc[:, len(df1) + i], where="post", linestyle="--", label=f"Individual {i + 1} (Second Half)")

plt.title('Cox Survival Curves for the Entire Dataset')
plt.xlabel('Time (in months)')
plt.ylabel('Survival Probability')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)

# %%
# 绘制生存曲线
plt.step(predicted_survival_1.index, predicted_survival_1.values, label='Group 1')
plt.step(predicted_survival_2.index, predicted_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7','RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7','RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# %%
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Cox analysis plot of BLCA')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value

# ... 其他代码，绘制图表 ...

# ... 其他代码 ...



# ... 其他代码，绘制图表 ...

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[ ['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7','RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[ ['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7','RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# %%
# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

#plt.xlabel('months')
#plt.ylabel('Survival Probability')
plt.title('BLCA')
# 在图中显示P值
# 在图中显示P值（使用科学计数法）
plt.text(30, 0.83, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\BRCA1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\BRCA2.csv')

# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['SLC39A9','SEL1L','CCDC124','TINF2','SDC1','AP2S1','MGST1','LYPLA2','FAM50A']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]

# %%
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))
# 创建 Cox 模型
cph = CoxPHFitter()
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values

# %%
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.6275787803219225

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[['SLC39A9','SEL1L','CCDC124','TINF2','SDC1','AP2S1','MGST1','LYPLA2','FAM50A']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['SLC39A9','SEL1L','CCDC124','TINF2','SDC1','AP2S1','MGST1','LYPLA2','FAM50A']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Average Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value
# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[ ['SLC39A9','SEL1L','CCDC124','TINF2','SDC1','AP2S1','MGST1','LYPLA2','FAM50A']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[ ['SLC39A9','SEL1L','CCDC124','TINF2','SDC1','AP2S1','MGST1','LYPLA2','FAM50A']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

#plt.xlabel('months')
#plt.ylabel('Survival Probability')
plt.title('BRCA')
plt.text(30, 0.83, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\HNSC1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\HNSC2.csv')

# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['PCMT1','TMSB10','KRT16P2','SNX3','SLC44A1','DIP2B']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))
# 创建 Cox 模型
cph = CoxPHFitter()
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values


# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.5953249389450982

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[['PCMT1','TMSB10','KRT16P2','SNX3','SLC44A1','DIP2B']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['PCMT1','TMSB10','KRT16P2','SNX3','SLC44A1','DIP2B']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Average Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value
# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[ ['PCMT1','TMSB10','KRT16P2','SNX3','SLC44A1','DIP2B']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['PCMT1','TMSB10','KRT16P2','SNX3','SLC44A1','DIP2B']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

#plt.xlabel('months')
#plt.ylabel('Survival Probability')
plt.title('HNSC')
plt.text(30, 0.79, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\KIRC1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\KIRC2.csv')

# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['PDK4','ERLEC1']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))
# 创建 Cox 模型
cph = CoxPHFitter()
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values


# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.5604168764474876

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[['PDK4','ERLEC1']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['PDK4','ERLEC1']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Average Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value
# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[ ['PDK4','ERLEC1']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[ ['PDK4','ERLEC1']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

#plt.xlabel('months')
#plt.ylabel('Survival Probability')
plt.title('KIRC')
plt.text(30, 0.79, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
#去除一个
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\LIHC1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\LIHC2.csv')

# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['ARF5','MRPS35','CPB2','C6','RHOA','CSDE1','PON1','GDI2','SPP2','STRAP','ITIH1','SEC61A1','C8B','PABPC1','YBX1','SCARB1','NDUFB4','CTNNA1','LASP1']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))
# 创建 Cox 模型
cph = CoxPHFitter()
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values


# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.6607223817439928

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[['ARF5','MRPS35','CPB2','C6','RHOA','CSDE1','PON1','GDI2','SPP2','STRAP','ITIH1','SEC61A1','C8B','PABPC1','YBX1','SCARB1','NDUFB4','CTNNA1','LASP1']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['ARF5','MRPS35','CPB2','C6','RHOA','CSDE1','PON1','GDI2','SPP2','STRAP','ITIH1','SEC61A1','C8B','PABPC1','YBX1','SCARB1','NDUFB4','CTNNA1','LASP1']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Average Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value
# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[ ['ARF5','MRPS35','CPB2','C6','RHOA','CSDE1','PON1','GDI2','SPP2','STRAP','ITIH1','SEC61A1','C8B','PABPC1','YBX1','SCARB1','NDUFB4','CTNNA1','LASP1']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[ ['ARF5','MRPS35','CPB2','C6','RHOA','CSDE1','PON1','GDI2','SPP2','STRAP','ITIH1','SEC61A1','C8B','PABPC1','YBX1','SCARB1','NDUFB4','CTNNA1','LASP1']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

#plt.xlabel('months')
#plt.ylabel('Survival Probability')
plt.title('LIHC')
plt.text(30, 0.78, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\LUAD1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\LUAD2.csv')

# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['PFKP','TYROBP','GDE1','CDC42','RAB20','TFPI']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))
# 创建 Cox 模型
cph = CoxPHFitter()
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values


# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.6235093696763203

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[['PFKP','TYROBP','GDE1','CDC42','RAB20','TFPI']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['PFKP','TYROBP','GDE1','CDC42','RAB20','TFPI']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Average Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value
# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[ ['PFKP','TYROBP','GDE1','CDC42','RAB20','TFPI']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[ ['PFKP','TYROBP','GDE1','CDC42','RAB20','TFPI']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

#plt.xlabel('months')
#plt.ylabel('Survival Probability')
plt.title('LUAD')
plt.text(30, 0.78, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\LUSC1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\LUSC2.csv')

# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['PLAU','SERPINB1','SLC39A9']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))
# 创建 Cox 模型
cph = CoxPHFitter()
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values


# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.602285675983645

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[['PLAU','SERPINB1','SLC39A9']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['PLAU','SERPINB1','SLC39A9']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Average Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value
# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[ ['PLAU','SERPINB1','SLC39A9']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['PLAU','SERPINB1','SLC39A9']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

#plt.xlabel('months')
#plt.ylabel('Survival Probability')
plt.title('LUSC')
plt.text(30, 0.77, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\OV1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\OV2.csv')

# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['ISOC1','CCNI','RTF2','PSMC4','CCNG1','MPZL2','PCMT1','PPP2CB','NOP58','TUSC3']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))
# 创建 Cox 模型
cph = CoxPHFitter()
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values


# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.6386477708886921

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[['ISOC1','CCNI','RTF2','PSMC4','CCNG1','MPZL2','PCMT1','PPP2CB','NOP58','TUSC3']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['ISOC1','CCNI','RTF2','PSMC4','CCNG1','MPZL2','PCMT1','PPP2CB','NOP58','TUSC3']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Average Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value
# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[ ['ISOC1','CCNI','RTF2','PSMC4','CCNG1','MPZL2','PCMT1','PPP2CB','NOP58','TUSC3']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[ ['ISOC1','CCNI','RTF2','PSMC4','CCNG1','MPZL2','PCMT1','PPP2CB','NOP58','TUSC3']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

#plt.xlabel('months')
#plt.ylabel('Survival Probability')
plt.title('OV')
plt.text(30, 0.8, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\SKCM1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\SKCM2.csv')

# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['MPV17','PHF23','AP001324.1','POLDIP2','LYPLA2','CDK5','GPKOW','TXNDC11']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))
# 创建 Cox 模型
cph = CoxPHFitter()
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values


# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.6575782239102912

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[['MPV17','PHF23','AP001324.1','POLDIP2','LYPLA2','CDK5','GPKOW','TXNDC11']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[['MPV17','PHF23','AP001324.1','POLDIP2','LYPLA2','CDK5','GPKOW','TXNDC11']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Average Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value
# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[ ['MPV17','PHF23','AP001324.1','POLDIP2','LYPLA2','CDK5','GPKOW','TXNDC11']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[ ['MPV17','PHF23','AP001324.1','POLDIP2','LYPLA2','CDK5','GPKOW','TXNDC11']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

plt.xlabel('months')
plt.ylabel('Survival Probability')
plt.title('SKCM')
plt.text(30, 0.83, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
#少一个tem
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\STAD1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\STAD2.csv')

# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列
#[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])['RALA','MDH1','NFE2L2','ATP5MC1','PCMT1','ZFAND5']
selected_genes = ['NFIX','TTYH3','RAB11B','TCF3','CHPF','AL928646.1','ZBTB7A','TLE5','TSPAN15','CYB561','UPF1','SCAMP4']
gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))
# 创建 Cox 模型
cph = CoxPHFitter()
# 拟合模型
cph.fit(df1, duration_col='SurvivalTime', event_col='event')
cph = CoxPHFitter(penalizer=0.01)
cph.fit(df2, duration_col='SurvivalTime', event_col='event')
# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1)
# 对前半组进行预测
predicted_hazard_1 = -cph.predict_partial_hazard(df1)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_1_values = predicted_survival_1.values


# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2)
# 对后半组进行预测
predicted_hazard_2 = -cph.predict_partial_hazard(df2)
# 获取预测生存曲线的列（通常是索引 0）
predicted_survival_2_values = predicted_survival_2.values
# 合并数据集
df = pd.concat([df1, df2], ignore_index=True)
# 拟合模型
cph = CoxPHFitter()
cph.fit(df, duration_col='SurvivalTime', event_col='event')
# 对整个数据集进行预测
predicted_hazard = -cph.predict_partial_hazard(df)
# 计算整个数据集的 C-index
c_index = concordance_index(event_times=df['SurvivalTime'], predicted_scores=predicted_hazard, event_observed=df['event'])
print(f"C-index for the entire dataset: {c_index}")
# Out:
# C-index for the entire dataset: 0.6405457532680906

# %%
import matplotlib.pyplot as plt

# 对前半组进行预测
predicted_survival_1 = cph.predict_survival_function(df1[ ['NFIX','TTYH3','RAB11B','TCF3','CHPF','AL928646.1','ZBTB7A','TLE5','TSPAN15','CYB561','UPF1','SCAMP4']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[ ['NFIX','TTYH3','RAB11B','TCF3','CHPF','AL928646.1','ZBTB7A','TLE5','TSPAN15','CYB561','UPF1','SCAMP4']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)
# 设置 x 轴范围为 0 到 150
plt.xlim(0, 110)
# 绘制生存曲线
plt.step(mean_survival_1.index, mean_survival_1.values, label='Group 1')
plt.step(mean_survival_2.index, mean_survival_2.values, label='Group 2')

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Average Cox Survival Curves for Group 1 and Group 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test

# ... 其他代码 ...

# 执行log-rank检验
results = logrank_test(df1['SurvivalTime'], df2['SurvivalTime'], event_observed_A=df1['event'], event_observed_B=df2['event'])
p_value = results.p_value
# 对前半组进行预测
#predicted_survival_1 = cph.predict_survival_function(df1[['CD74', 'PSMB1', 'HSP90B1', 'HSPA5', 'CCT7']])
predicted_survival_1 = cph.predict_survival_function(df1[  ['NFIX','TTYH3','RAB11B','TCF3','CHPF','AL928646.1','ZBTB7A','TLE5','TSPAN15','CYB561','UPF1','SCAMP4']])
# 对后半组进行预测
predicted_survival_2 = cph.predict_survival_function(df2[  ['NFIX','TTYH3','RAB11B','TCF3','CHPF','AL928646.1','ZBTB7A','TLE5','TSPAN15','CYB561','UPF1','SCAMP4']])

# 取每个时间点的平均值，得到前半组和后半组的平均生存曲线
mean_survival_1 = predicted_survival_1.mean(axis=1)
mean_survival_2 = predicted_survival_2.mean(axis=1)

# 计算 x 轴范围
min_time = min(mean_survival_1.index.min(), mean_survival_2.index.min())
max_time = max(mean_survival_1.index.max(), mean_survival_2.index.max())

# 设置 x 轴范围为 0 到 150
plt.xlim(0, 60)

# 绘制生存曲线，指定颜色
plt.step(mean_survival_1.index, mean_survival_1.values, label='Low survival group', color='red')
plt.step(mean_survival_2.index, mean_survival_2.values, label='High survival group', color='blue')

plt.xlabel('months')
plt.ylabel('Survival Probability')
plt.title('STAD')
plt.text(30, 0.77, f'Log-rank p-value: {p_value:.2e}', fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.8))
plt.legend()
plt.show()

# %%
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
# 读取第一个CSV文件
df1 = pd.read_csv('g:\\33x33BLCA1.csv')
# 读取第二个CSV文件
df2 = pd.read_csv('g:\\33x33BLCA2.csv')

# %%
import pandas as pd

# 从CSV文件中读取数据
df1 = pd.read_csv('g:\\33x33BLCA1.csv')  # 替换成你的实际文件路径
df2 = pd.read_csv('g:\\33x33BLCA2.csv')
# 获取除了'event'和'days_to_death'列之外的所有列名
columns_to_exclude = ['event', 'days_to_death','case_id','file_id','GBP1P1', 'ST6GALNAC2', 'HOXD4', 'FGFR2', 'TLL1', 'FMO3', 'NAMPTP1', 'MAD1L1', 'PRSS3', 'CD79B', 'AC005332.3', 'CYP4F22', 'EPN3', 'AC023043.4', 'DPF1', 'NOX1', 'SOX8', 'DRD4', 'OR7E14P', 'RSPH9', 'SurvivalTime', 'CHRDL2', 'ACP3', 'CADM4', 'FMO1', 'HES2', 'PLEKHB1', 'VSIG2', 'AL133520.1', 'PTMAP9', 'CD84', 'ST6GALNAC1', 'CNTN1', 'SYN1', 'HSD17B6', 'MIR1244-2', 'AL161430.1', 'NRXN3', 'COL6A6', 'RASGRF1', 'AC130371.2', 'HSPB6', 'AC020910.5', 'PTGES3P1', 'AC092794.1', 'SLC25A4', 'NOS2', 'SLC1A7']
selected_genes = [col for col in df1.columns if col not in columns_to_exclude]

# 打印结果
print(selected_genes)
# Out:
# ['CDH19', 'ABCB4', 'AC022079.1', 'AC091825.1', 'CAMK2B', 'CPS1', 'DNAH5', 'GPR83', 'GRAMD1B', 'GUCA2B', 'H4C6', 'ITGA2B', 'LINC01215', 'MYOM2', 'NAV3', 'NKX3-2', 'PKHD1', 'PTPRN', 'RNU6-890P', 'RNU7-186P', 'SLC6A15', 'SLC7A9', 'SLC9A3', 'SPTB', 'TENM1', 'TFAP2B', 'TNFSF18', 'TRPM5', 'UTS2', 'WNT16', 'TKTL1', 'KLHL13', 'POU2F2', 'ADAM28', 'ACSM3', 'MIR7152', 'RASGRP2', 'ABCC2', 'ADRB1', 'FLT4', 'RNVU1-27', 'RIPOR3', 'AC011472.1', 'KRIT1', 'BFSP1', 'RPL23AP64', 'PCDHB16', 'TG', 'MIR378J', 'ETV1', 'ARHGAP6', 'MYOC', 'MRPL2', 'AC026356.1', 'CD38', 'TSPOAP1', 'RGS9', 'ANKRD44', 'MASP2', 'GNAT3', 'CCKBR', 'SPRTN', 'RAD52', 'AL135999.3', 'ASTE1', 'PRSS21', 'ALS2', 'PDZD4', 'FARP2', 'AASS', 'GABRA3', 'PMS2P4', 'PKD1', 'TRMT11', 'BAIAP3', 'USP13', 'CASTOR2', 'CLCN6', 'LNX1', 'AC008764.2', 'AC012354.2', 'ANOS1', 'ATG2B', 'EML1', 'RASAL3', 'DYRK4', 'TFB1M', 'ZNF195', 'ZRANB1', 'MAP1LC3C', 'HAGLR', 'MLXIPL', 'LRRC23', 'NATD1', 'ANGEL1', 'ZIC2', 'TP53BP1', 'TBXA2R', 'POLR3B', 'FECH', 'GIMAP2', 'ENTPD2', 'ADPRM', 'ALG1', 'APBA3', 'MRRF', 'ATP11A', 'SCML1', 'SELE', 'KDM7A', 'BRCA1', 'TESK2', 'CDK14', 'KIF26A', 'MAP3K14', 'CADPS2', 'YTHDC2', 'TRAF1', 'SPAST', 'SLC4A7', 'SLC7A2', 'CAMK1G', 'PRKAR2B', 'MIR6081', 'PKP2', 'PNPLA4', 'USP28', 'ZFYVE26', 'HEATR5B', 'BTK', 'SRBD1', 'RAB27A', 'CARNMT1', 'PCCA-DT', 'TBC1D4', 'PEX3', 'PGM3', 'RABEP1', 'TMEM260', 'SNAPC1', 'HIVEP2', 'FAM214A', 'JADE2', 'DAPP1', 'MATK', 'PRKCH', 'FAM214B', 'HS3ST1', 'ZDHHC2', 'MTA3', 'CROCC', 'FUT8', 'ZNF280B', 'EXTL3', 'AL590682.1', 'MRE11', 'PIGQ', 'PHF19', 'MAP11', 'CYB5R4', 'JMJD6', 'LINC00467', 'WDR37', 'ALDH3A2', 'EHD3', 'AGPS', 'MIPEP', 'IBTK', 'RBM5', 'BARX2', 'TGFBR3', 'MEIS1', 'RECQL', 'TIE1', 'LRRC40', 'ABHD5', 'MMP25', 'COX15', 'CREBBP', 'BRD9', 'DCBLD2', 'WIPI1', 'CYTH3', 'ROCK1', 'RN7SL166P', 'KCNQ1', 'CLDN18', 'TDP1', 'RNF14', 'POLB', 'TTC7A', 'ARHGAP31', 'SLC30A9', 'TRO', 'CCDC88C', 'MAN2B2', 'LMCD1', 'UBR2', 'TTC27', 'INPP5A', 'ARNTL2', 'OFD1', 'ZNF142', 'VTA1', 'ERAP1', 'LIG3', 'MPND', 'MAP4K3', 'PLA2G10', 'TBC1D23', 'JARID2', 'MAOB', 'CALCOCO1', 'FOXC1', 'EFNB2', 'MARK4', 'AC009804.1', 'GAL', 'ANAPC4', 'NDST1', 'WIZ', 'ETV6', 'SYT1', 'NFYC', 'KCNAB2', 'SKAP2', 'SH3YL1', 'CD4', 'METTL1', 'GRIPAP1', 'RCE1', 'CDC27', 'LY75', 'MLLT6', 'SEL1L', 'ITGB8', 'ELN', 'ARFIP2', 'HOXC8', 'CTSW', 'ZNF207', 'RANBP3', 'LTF', 'AL590867.2', 'ATP11B', 'BEST2', 'ZXDC', 'IGLON5', 'ALDH3B1', 'PPP4R3B', 'TCOF1', 'RANBP9', 'ECHDC3', 'NLRP2', 'ZFY', 'ARHGAP10', 'NMI', 'FZD1', 'NR1H3', 'TCEAL3', 'LSG1', 'CFAP36', 'HYAL2', 'TRIB2', 'SPATA20', 'DERA', 'MNT', 'UTP11', 'CFAP20', 'PAGE1', 'ATP2B1', 'FAM3A', 'ATP6V1H', 'BAIAP2L1', 'PTPN18', 'PHYH', 'PDIA5', 'PAX7', 'ZZZ3', 'STAP1', 'ARID4B', 'IGKJ1', 'RNF216', 'RAI14', 'KAT6A', 'RPL26L1', 'VPS13D', 'TRIP13', 'NEO1', 'NDUFS1', 'ZFR', 'IP6K2', 'ISOC1', 'SEC62', 'CLCA4', 'ING3', 'HPF1', 'CBFB', 'KDM5D', 'ELAVL1', 'SMARCD1', 'RPS6KA6', 'B4GALT7', 'CCDC28A', 'RNF126', 'PHF23', 'ATP2C1', 'AL035661.1', 'ERCC1', 'ARX', 'MTMR11', 'STAG3', 'POLR1H', 'MARCHF7', 'DVL2', 'RTF2', 'RTN4R', 'PFKP', 'MEOX1', 'ZFX', 'SLC35B1', 'TRIO', 'ARSD', 'TMEM132A', 'PRSS22', 'GDE1', 'MAP4', 'IFT80', 'FUNDC1', 'CXCL9', 'ZCCHC8', 'CYP24A1', 'RALA', 'CHDH', 'SIN3B', 'MRC2', 'CPSF1', 'CUL1', 'ALOX5', 'RARS1', 'COPZ2', 'ROPN1L', 'WAS', 'CNGB1', 'C12orf4', 'UBE3C', 'CEACAM7', 'BCL3', 'PRKCZ', 'FSTL3', 'XK', 'GBA2', 'PRICKLE3', 'MARCO', 'KIAA0100', 'RALBP1', 'IFNGR1', 'SNAI2', 'MDH1', 'CELSR3', 'COL15A1', 'GGCT', 'PIAS1', 'ANAPC13', 'AP2B1', 'THUMPD1', 'HMGB3', 'ABCF1', 'TRAPPC6A', 'NRBP1', 'DGCR2', 'EFCAB14', 'NPC1L1', 'AP3M2', 'USH1C', 'THAP3', 'SLC39A9', 'RASSF1', 'PFN2', 'LARS2', 'OTUD5', 'MAP3K9', 'STAB1', 'IL20RA', 'PHF20', 'MAPK6', 'KLF6', 'RHBDD2', 'RCC1L', 'HMGN3', 'IFT88', 'TNFRSF1B', 'CLTC', 'GAS7', 'TCF3', 'FAM50A', 'CEACAM21', 'DTNBP1', 'BZW2', 'MVP', 'TSR3', 'CTNNA1', 'ATP6AP1', 'SCMH1', 'ALOXE3P1', 'FUZ', 'ART5', 'CRY1', 'RBM6', 'SLC38A5', 'STRAP', 'ARAP2', 'TNC', 'H3C8', 'PDK2', 'SLC25A13', 'DIP2B', 'PTRH2', 'CROT', 'NUCKS1', 'TRAM1', 'CIAPIN1', 'SLC25A39 ...

# %%
# 将生存时间转换为月
df1['SurvivalTime'] = df1['days_to_death'] / 30.44
df2['SurvivalTime'] = df2['days_to_death'] / 30.44

# 选择基因列

gene_columns = ['event', 'SurvivalTime'] + selected_genes

# 设置选择相关列
df1 = df1[gene_columns]
df2 = df2[gene_columns]
# 进行两两配对，删除规则不符合的对子
matched_pairs = []

for i, row1 in df1.iterrows():
    for j, row2 in df2.iterrows():
        if row1['event'] == 1 and row2['event'] == 1 and row1['SurvivalTime'] < row2['SurvivalTime']:
            matched_pairs.append((i, j))

# %%
# 打印所有列名
print("df1 列名:", df1.columns)
print("df2 列名:", df2.columns)
# Out:
# df1 列名: Index(['event', 'SurvivalTime', 'CDH19', 'ABCB4', 'AC022079.1', 'AC091825.1',
#        'CAMK2B', 'CPS1', 'DNAH5', 'GPR83',
#        ...
#        'CHAT', 'ITIH1', 'ABCB5', 'OTC', 'HHATL', 'FP236383.1', 'SLC18A1',
#        'AC020656.2', 'SLC6A13', 'SLC12A1'],
#       dtype='object', length=1043)
# df2 列名: Index(['event', 'SurvivalTime', 'CDH19', 'ABCB4', 'AC022079.1', 'AC091825.1',
#        'CAMK2B', 'CPS1', 'DNAH5', 'GPR83',
#        ...
#        'CHAT', 'ITIH1', 'ABCB5', 'OTC', 'HHATL', 'FP236383.1', 'SLC18A1',
#        'AC020656.2', 'SLC6A13', 'SLC12A1'],
#       dtype='object', length=1043)

# %%
# 检查每列是否存在缺失值
missing_values = df2.isnull().sum()

# 打印存在缺失值的列
print("存在缺失值的列：")
print(missing_values[missing_values > 0])
# Out:
# 存在缺失值的列：
# Series([], dtype: int64)

# %%
# 使用描述性统计信息查看每列的分布
descriptive_stats = df1.describe()

# 打印描述性统计信息
print(descriptive_stats)
# Out:
#        event  SurvivalTime      CDH19      ABCB4  AC022079.1  AC091825.1  \
# count   95.0     95.000000  95.000000  95.000000   95.000000   95.000000
# mean     1.0      7.056159   0.304820   0.198071    0.336202    0.483365
# std      0.0      3.614422   0.722313   0.210436    0.876405    2.744129
# min      1.0      0.000000   0.000000   0.014800    0.000000    0.000000
# 25%      1.0      4.106439   0.006600   0.073650    0.038500    0.000000
# 50%      1.0      7.325887   0.034500   0.131700    0.101100    0.000000
# 75%      1.0      9.806176   0.112800   0.217050    0.195500    0.243800
# max      1.0     13.140604   4.455300   1.175400    5.210700   26.542500
#
#           CAMK2B       CPS1      DNAH5      GPR83  ...       CHAT      ITIH1  \
# count  95.000000  95.000000  95.000000  95.000000  ...  95.000000  95.000000
# mean    0.269276   0.462806   0.309377   0.671223  ...   0.048812   0.041623
# std     0.733087   0.745487   0.447464   6.085308  ...   0.156737   0.143426
# min     0.000000   0.003400   0.006500   0.000000  ...   0.000000   0.000000
# 25%     0.028900   0.046600   0.069900   0.018400  ...   0.000000   0.000000
# 50%     0.057500   0.115800   0.159800   0.031500  ...   0.002700   0.006800
# 75%     0.136450   0.465750   0.413700   0.055800  ...   0.014200   0.028400
# max     5.944800   3.923300   2.939400  59.355100  ...   0.980600   1.212100
#
#            ABCB5        OTC      HHATL  FP236383.1    SLC18A1  AC020656.2  \
# count  95.000000  95.000000  95.000000        95.0  95.000000   95.000000
# mean    0.044613   0.026055   0.021825         0.0   0.023568    0.046373
# std     0.122991   0.106968   0.059472         0.0   0.118195    0.167058
# min     0.000000   0.000000   0.000000         0.0   0.000000    0.000000
# 25%     0.000000   0.000000   0.000000         0.0   0.000000    0.002450
# 50%     0.003000   0.000000   0.000000         0.0   0.004300    0.009100
# 75%     0.016800   0.008900   0.016150         0.0   0.011200    0.027450
# max     0.742800   0.653900   0.448900         0.0   1.130500    1.521500
#
#          SLC6A13    SLC12A1
# count  95.000000  95.000000
# mean    0.077497   0.006077
# std     0.195401   0.012030
# min     0.000000   0.000000
# 25%     0.006300   0.000000
# 50%     0.021200   0.002000
# 75%     0.044050   0.004950
# max     1.492700   0.073100
#
# [8 rows x 1043 columns]
